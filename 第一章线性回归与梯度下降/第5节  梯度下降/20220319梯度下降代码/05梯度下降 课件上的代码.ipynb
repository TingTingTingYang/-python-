# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams["font.family"] = "SimHei"
plt.rcParams["axes.unicode_minus"] = False
plt.rcParams["font.size"] = 12


import warnings
warnings.filterwarnings("ignore", category=FutureWarning, module="sklearn", lineno=87)

# %%
def f(x):
    return x ** 2

x = np.linspace(-10, 10, 100)
plt.plot(x, f(x))
# 定义两个初始点。
x1, x2 = 7.5, -8.5
plt.plot(x1, f(x1), marker="*", ms=15, color="r", label="初始点1")
plt.plot(x2, f(x2), marker="*", ms=15, color="g", label="初始点2")
plt.axvline(ls="--", c="black")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()

# %%
def fun(x):
    return x ** 2 - 2 * x + 1

def grad_f(x):
    return 2 * x - 2


def grad_descent(f, g, x_init, eta=0.1, tol=1e-4, max_iter=100, verbose=True):
    x_list = []
    y_list = []
    x = x_init

    for i in range(max_iter):
        x_list.append(x)
        y = f(x)
        y_list.append(y)
        # 如果在两次迭代中，函数y比上一次的减少值小于tol，则停止迭代。
        if len(y_list) >= 2 and y_list[-2] - y < tol:
            break

        x -= eta * g(x)
    if verbose:
        for index, (a, b) in enumerate(zip(x_list, y_list), start=1):
            print(f"第{index}次迭代，x={a}, y={b}")
    return x_list, y_list

x_list, y_list = grad_descent(fun, grad_f, x_init=10)
# Out:
# 第1次迭代，x=10, y=81
# 第2次迭代，x=8.2, y=51.839999999999996
# 第3次迭代，x=6.76, y=33.1776
# 第4次迭代，x=5.608, y=21.233663999999997
# 第5次迭代，x=4.6864, y=13.58954496
# 第6次迭代，x=3.9491199999999997, y=8.697308774399998
# 第7次迭代，x=3.3592959999999996, y=5.5662776156159985
# 第8次迭代，x=2.8874367999999997, y=3.562417673994238
# 第9次迭代，x=2.5099494399999998, y=2.279947311356313
# 第10次迭代，x=2.2079595519999997, y=1.4591662792680404
# 第11次迭代，x=1.9663676415999998, y=0.9338664187315455
# 第12次迭代，x=1.7730941132799998, y=0.5976745079881893
# 第13次迭代，x=1.6184752906239999, y=0.38251168511244105
# 第14次迭代，x=1.4947802324992, y=0.24480747847196227
# 第15次迭代，x=1.3958241859993599, y=0.15667678622205594
# 第16次迭代，x=1.316659348799488, y=0.10027314318211578
# 第17次迭代，x=1.2533274790395903, y=0.06417481163655414
# 第18次迭代，x=1.2026619832316723, y=0.041071879447394544
# 第19次迭代，x=1.1621295865853378, y=0.026286002846332535
# 第20次迭代，x=1.1297036692682703, y=0.01682304182165284
# 第21次迭代，x=1.1037629354146161, y=0.01076674676585787
# ...

# %%
def plot_result(f, x, x_li, y_li):
    y = f(x)
    plt.plot(x, y, c="y")
    plt.title("函数$y=x^{2}-2x+1$的图像")

    plt.plot(x_list, y_list, marker="o", ls="--", c="r")
    plt.plot(x_list[0], y_list[0], marker="*", ms=15, c="b", label="初始点")
    plt.plot(x_list[-1], y_list[-1], marker="*", ms=15, c="g", label="终止点")
    plt.legend()
    plt.show()

domain = np.linspace(-9, 11, 200)
plot_result(fun, domain, x_list, y_list)

# %%
x_list, y_list = grad_descent(fun, grad_f, x_init=10, eta=0.3)
plot_result(fun, domain, x_list, y_list)
# Out:
# 第1次迭代，x=10, y=81
# 第2次迭代，x=4.6000000000000005, y=12.960000000000003
# 第3次迭代，x=2.4400000000000004, y=2.0736000000000008
# 第4次迭代，x=1.576, y=0.33177600000000007
# 第5次迭代，x=1.2304, y=0.05308416000000005
# 第6次迭代，x=1.09216, y=0.008493465599999972
# 第7次迭代，x=1.036864, y=0.0013589544959999866
# 第8次迭代，x=1.0147456, y=0.0002174327193600334
# 第9次迭代，x=1.00589824, y=3.478923509758758e-05
# 第10次迭代，x=1.002359296, y=5.566277615720594e-06

# %%
x_list, y_list = grad_descent(fun, grad_f, x_init=10, eta=0.7)
plot_result(fun, domain, x_list, y_list)
# Out:
# 第1次迭代，x=10, y=81
# 第2次迭代，x=-2.5999999999999996, y=12.959999999999997
# 第3次迭代，x=2.4399999999999995, y=2.073599999999999
# 第4次迭代，x=0.4240000000000004, y=0.3317759999999996
# 第5次迭代，x=1.2304, y=0.05308416000000005
# 第6次迭代，x=0.90784, y=0.008493465599999972
# 第7次迭代，x=1.036864, y=0.0013589544959999866
# 第8次迭代，x=0.9852544, y=0.0002174327193600334
# 第9次迭代，x=1.00589824, y=3.478923509758758e-05
# 第10次迭代，x=0.9976407039999999, y=5.566277615609572e-06

# %%
x_list, y_list = grad_descent(fun, grad_f, x_init=5, eta=1.5)
plot_result(fun, domain, x_list, y_list)
# Out:
# 第1次迭代，x=5, y=16
# 第2次迭代，x=-7.0, y=64.0

# %%
x_list, y_list = grad_descent(fun, grad_f, x_init=10, eta=0.005, verbose=False)
plot_result(fun, domain, x_list, y_list)

# %%
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib qt

def fun(x1, x2):
    return 0.2 * (x1 + x2) ** 2 - 0.3 * x1 * x2 + 0.4

def grad_f_x1(x1, x2):
    return 0.4 * (x1 + x2) - 0.3 * x2

def grad_f_x2(x1, x2):
    return 0.4 * (x1 + x2) - 0.3 * x1

def grad_descent(f, g, x_init, eta=0.1, tol=1e-4, max_iter=100, verbose=True):
    # 定义x_list与y_list，用来保存梯度下降过程中，自变量x与函数值y的更新轨迹。
    x_list = []
    y_list = []
    x1, x2 = x_init
    g1, g2 = g
    for i in range(max_iter):
        x_list.append((x1, x2))
        y = f(x1, x2)
        y_list.append(y)
        # 如果在两次迭代中，函数y比上一次的减少值小于tol，则停止迭代。
        if len(y_list) >= 2 and y_list[-2] - y < tol:
            break
        x1 -= eta * g1(x1, x2)
        x2 -= eta * g2(x1, x2)
    if verbose:
        for index, (a, b) in enumerate(zip(x_list, y_list), start=1):
            print(f"第{index}次迭代，x={a}, y={b}")
    return x_list, y_list

x_list, y_list = grad_descent(fun, g=(grad_f_x1, grad_f_x2), x_init=(4.8, 4.5), eta=0.4)
# Out:
# 第1次迭代，x=(4.8, 4.5), y=11.218000000000002
# 第2次迭代，x=(3.8519999999999994, 3.62592), y=7.393744353280001
# 第3次迭代，x=(3.0906431999999993, 2.9221470719999996), y=4.921335177768551
# 第4次迭代，x=(2.4792544051199994, 2.3554333642751994), y=3.322925602204132
# 第5次迭代，x=(1.9883563657297916, 1.899029771361976), y=2.2895698153912587
# 第6次迭代，x=(1.5942581563585458, 1.5314146816897178), y=1.6215250339872198
# 第7次迭代，x=(1.2779202640735898, 1.2352715220564194), y=1.1896530378735917
# 第8次迭代，x=(1.0240421609395587, 0.99666639208981), y=0.9104640894897645
# 第9次迭代，x=(0.8203287595056369, 0.8043866189752149), y=0.729981569022374
# 第10次迭代，x=(0.6569006932257264, 0.6494087322101514), y=0.6133097490838161
# 第11次迭代，x=(0.5258202330212041, 0.524470525735679), y=0.5378889713694954
# 第12次迭代，x=(0.42071017470838423, 0.42372683462963495), y=0.4891349153602483
# 第13次迭代，x=(0.33644747336985736, 0.34247264215409906), y=0.4576192881072987
# 第14次迭代，x=(0.26891697194451625, 0.2769203405316626), y=0.43724710050455784
# ...

# %%
def plot_result(f, x, x_li, y_li):
    x1, x2 = x
    X1, X2 = np.meshgrid(x1, x2)
    X = np.array([X1.ravel(), X2.ravel()]).T
    y = f(X[:, 0], X[:, 1])
    Y = y.reshape(X1.shape)
    fig = plt.figure()
    ax = Axes3D(fig)
    surf = ax.plot_surface(X1, X2, Y, rstride=5, cstride=5, cmap="rainbow",
    alpha=0.8)
    # 将自变量的轨迹列表转换为ndarray数组，方便按列单独提取x1与x2的轨迹。
    array = np.asarray(x_li)
    x1_trace = array[:, 0]
    x2_trace = array[:, 1]
    ax.plot(x1_trace, x2_trace, y_list, c="b", ls="--", marker="o")
    ax.set_title("函数$y = 0.2(x1 + x2) ^ {2} - 0.3x1x2 + 0.4$")
    # 绘制三维图时，参数必须是数组类型，不支持标量，这点与绘制二维图不同。
    ax.plot(x1_trace[0:1], x2_trace[0:1], y_list[0:1], marker="*", ms=15, c="b",
    label="初始点")
    ax.plot(x1_trace[-1:], x2_trace[-1:], y_list[-1:], marker="*", ms=15, c="g",
    label="终止点")
    # 为曲面对象增加颜色条。
    fig.colorbar(surf)
    ax.legend()
    # 创建新的画布，用来绘制等高线图。
    fig2 = plt.figure()
    ax2 = fig2.gca()
    m = ax2.contourf(X1, X2, Y, 10)
    ax2.scatter(x1_trace, x2_trace, c="r")
    # 为等高线图增加颜色条。
    fig2.colorbar(m)
    ax2.set_title("轨迹更新投影图")
    plt.show()

x1_domain = np.arange(-5, 5, 0.1)
x2_domain = np.arange(-5, 5, 0.1)
plot_result(fun, (x1_domain, x2_domain), x_list, y_list)

# %%
from sklearn.linear_model import SGDRegressor
from sklearn.datasets import make_regression

X, y, coef = make_regression(n_samples=1000, n_features=5, bias=2.5, coef=True,
noise=5, random_state=0)
print(f"真实权重：{coef}")
# eta0 指定学习率
sgd = SGDRegressor(eta0=0.2)
sgd.fit(X, y)
print(f"预测权重：{sgd.coef_}")
print(f"预测截距：{sgd.intercept_}")
print(f"R^2值：{sgd.score(X, y)}")
# Out:
# 真实权重：[41.20593377 66.49948238 10.71453179 60.19514224 25.96147771]
# 预测权重：[41.08313698 67.13570369 11.29831709 60.36406883 25.07984993]
# 预测截距：[2.48351596]
# R^2值：0.9973560952740531

# %%
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, SGDRegressor

X, y = load_boston(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25,
random_state=0)
lr = LinearRegression()
lr.fit(X_train, y_train)
print("线性回归拟合分值：")
print(lr.score(X_train, y_train))
print(lr.score(X_test, y_test))
sgd = SGDRegressor(max_iter=100, eta0=0.01)
sgd.fit(X_train, y_train)
print("随机梯度下降拟合分值：")
print(sgd.score(X_train, y_train))
print(sgd.score(X_test, y_test))
# Out:
# 线性回归拟合分值：
# 0.7697699488741149
# 0.6354638433202129
# 随机梯度下降拟合分值：
# -6.237136517987817e+25
# -6.4379391814962745e+25
# D:\software\Anaconda3\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:1507: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   ConvergenceWarning,

# %%
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split
from sklearn.linear_model import SGDRegressor
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, MinMaxScaler

X, y = load_boston(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25,
random_state=0)
pipeline = Pipeline([("ss", StandardScaler()), ("sgd", SGDRegressor(eta0=0.01, max_iter=100))])
# pipeline = Pipeline([("ss", MinMaxScaler((-1, 1))), ("sgd", SGDRegressor(eta0=0.01, max_iter=100))])
pipeline.fit(X_train, y_train)
print(pipeline.score(X_train, y_train))
print(pipeline.score(X_test, y_test))
# Out:
# 0.7687557041938557
# 0.6227810214572541
